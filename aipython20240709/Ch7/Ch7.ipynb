# %%
sum=0
dic1 = {}
while True:
    item = input("消費項目")
    price = input("消費金額")   
    try:
        if  sum + int(price) > 1000:
            raise OverflowError
        dic1[item] = price            
        sum+=int(price)   
    except OverflowError:
         print('已經超支了')
         break  
print(dic1)
# Out:
# 消費項目 AA
# 消費金額 100
# 消費項目 BB
# 消費金額 200
# 消費項目 CCC
# 消費金額 500
# 消費項目 GG
# 消費金額 200
# 消費項目 DD
# 消費金額 1
# 已經超支了
# {'AA': '100', 'BB': '200', 'CCC': '500', 'GG': '200'}

# %% [markdown]
# ## 檔案存取
#
# file object = open(file_name [, access_mode])
#
# UTF8 編碼資料還請加入另一個參數才可避免亂碼：encoding=‘utf-8'
# file object = open(file_name [, access_mode])
#
# 參數說明
#
# file_name：file_name 參數是一個字串資料，代表包含要連結的文件名稱。
#
# access_mode：access_mode 確定文件必須打開的模式，包括讀取、寫入、附加等等。稍後會列完整列表。這是可選參數，默認文件訪問模式為讀取(r)。
#
# |模式	|可做操作|若檔案不存在|是否覆蓋|
# |----|--------|-----------|-------|
# |r	|只能讀|報錯	|-|
# |r+	|可讀可寫|報錯|是|
# |w	|只能寫|建立|是|
# |w+ |可讀可寫|建立|是|
# |a　|只能寫|建立|否，追加寫|
# |a+	|可讀可寫|建立|否，追加寫|

# %%
text = """python與中文AAA
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
"""
print(text,file=open("data.txt","w",encoding="utf-8"))

# %%
dataList = []
while True:
    score = input("請輸入數字:(quit離開)")
    if score == "quit":
        break
    dataList.append(score)    
#print(str(dataList))
dataStr = str(dataList)
file = open("score.txt","w",encoding="utf-8")
file.write(dataStr)
file.close()
# Out:
# 請輸入數字:(quit離開) 1--
# 請輸入數字:(quit離開) 20
# 請輸入數字:(quit離開) 500
# 請輸入數字:(quit離開) quit

# %%
f = open("data.txt","r",encoding="UTF-8")
content = f.read()
print(content)
f.close()
# Out:
# python與中文AAA
# 1. 我們來試試看中文儲存能力。
# 2. 許這個字會有編碼衝突風險。
# 3. 犇這個字必須是utf8編碼才有。

# %% [markdown]
# ## CSV
# + CSV 格式是資料庫最常用的導入和導出格式。
# + 資料均沒有類型，一切都是字串。
# + 沒有字體或顏色與儲存格寬度高度的設置。
# + Python 語法必須加入 import csv。
# + 讀取儲存格資料：
#   + reader( )：依照每一列的編號 由0開始
#   + DictReader( )
#     + 以第一列的值為每一行的名稱，第一列不是資料
#     + 也可以重新命名，但第一列必須是資料

# %% [markdown]
# ### Read

# %%
import csv
f =  open("./example1.csv","r")
for row in csv.reader(f):
    if  float(row[5]) > 100:
        print(row[0],row[1],row[2],sep="#")
f.close()
# Out:
#  104/01/03#2,640,781,030#64,138,886,194
#  104/01/17#3,720,277,205#101,133,309,290
#  104/01/30#4,540,373,544#143,900,658,474
#  104/01/31#5,486,734,180#162,361,181,834

# %%
import csv
f = open("./example.csv","r",encoding="utf-8")
for row in csv.DictReader(f):
    if float(row["漲跌點數"]) > 9.34:
        print(row["漲跌點數"])
f.close()
# Out:
# 101.17
# 29.59
# 47.89
# 85.83
# 117.46
# 12.61
# 173.72
# 109.67

# %%
import csv
f =  open("./example1.csv","r")
csvData = csv.reader(f)
print(type(csvData))
csvList = list(csvData)
print(type(csvList))
print(csvList)
# Out:
# <class '_csv.reader'>
# <class 'list'>
# [[' 104/01/02', '2,104,640,545', '50,472,201,894', '497,889', '6,952.21', '-119.87'], [' 104/01/03', '2,640,781,030', '64,138,886,194', '623,192', '7,053.38', '101.17'], [' 104/01/04', '2,983,756,821', '75,845,629,353', '728,417', '7,082.97', '29.59'], [' 104/01/05', '3,062,757,248', '76,850,752,698', '737,780', '7,130.86', '47.89'], [' 104/01/06', '3,314,147,435', '88,101,921,548', '823,810', '7,120.51', '-10.35'], [' 104/01/09', '2,610,433,477', '71,323,370,369', '634,137', '7,093.04', '-27.47'], [' 104/01/10', '3,595,611,551', '97,168,542,017', '869,327', '7,178.87', '85.83'], [' 104/01/11', '3,322,390,467', '88,786,671,892', '802,539', '7,188.21', '9.34'], [' 104/01/12', '2,969,248,375', '78,947,910,460', '731,328', '7,186.58', '-1.63'], [' 104/01/13', '3,497,838,901', '99,286,437,370', '819,762', '7,181.54', '-5.04'], [' 104/01/16', '3,184,795,667', '76,842,611,338', '719,725', '7,103.62', '-77.92'], [' 104/01/17', '3,720,277,205', '101,133,309,290', '899,597', '7,221.08', '117.46'], [' 104/01/18', '4,088,756,925', '113,988,641,382', '1,020,420', '7,233.69', '12.61'], [' 104/01/30', '4,540,373,544', '143,900,658,474', '1,113,727', '7,407.41', '173.72'], [' 104/01/31', '5,486,734,180', '162,361,181,834', '1,283,951', '7,517.08', '109.67']]

# %% [markdown]
# ## JSON

# %% [markdown]
# ![image.png](attachment:c133b769-1064-414e-b498-5c8f3f8f8f14.png)

# %% [markdown]
# ### Json 轉為 Python物件
# + 以 json.loads( ) 函數從 JSON 字串中取出資料轉入 Python。
# + 以 json.load( ) 函數從 JSON 檔案中取出資料轉入 Python。

# %%
import json
json1 = '{"python":"good","gjun":100,"python-class":true,"ICQ":null}'
json2 = json.loads(json1)
print(type(json2))
print(json2)
# Out:
# <class 'dict'>
# {'python': 'good', 'gjun': 100, 'python-class': True, 'ICQ': None}

# %%
import json
with open("./data.json","r",encoding="utf-8") as jsonFile:
    data = json.load(jsonFile)
    print(data)
    for k in data:
        #print(f"{k}-{data[k]}")      
        for d2 in data[k]:
            info = f"name:{d2['name']} website:{ d2['website']} from: {d2['from']} "
            print(info)
        
        #print(info) #Name:Scott  website: stackabuse.com from Nebraska
# Out:
# {'people': [{'name': 'Scott', 'website': 'stackabuse.com', 'from': 'Nebraska'}, {'name': 'Larry', 'website': 'google.com', 'from': 'Michigan'}]}
# name:Scott website:stackabuse.com from: Nebraska
# name:Larry website:google.com from: Michigan

# %%
import json
with open("./data.json","r",encoding="utf-8") as jsonFile:
    data = json.load(jsonFile)
    print(data)
    for k in data:     
        for d2 in data[k]:
            info=""
            for k2 in d2:
              info += f"{k2}:{d2[k2]} "  
            print(info)
# Out:
# {'people': [{'name': 'Scott', 'website': 'stackabuse.com', 'from': 'Nebraska'}, {'name': 'Larry', 'website': 'google.com', 'from': 'Michigan'}]}
# name:Scott website:stackabuse.com from:Nebraska
# name:Larry website:google.com from:Michigan

# %% [markdown]
# ## 關於檔案關閉動作
# + 檔案開啟後須進行 close( ) 方法進行關閉動作。
# + 若檔案沒關閉會造成：
#   + 開啟的文件物件會占用系統資源。
#   + Python 可以同時間開啟的文件數量有限制 (約 20 份文件)。
#   + 開啟文件物件的模式若為寫入 (w 或 a) 模式，一般都是暫存於緩衝區，系統閒置或文件關閉前才會進行寫入，若沒有進行 close( ) 動作可能造成文件儲存不完整。

# %%
import os
class TestFile:
     def openFile(self,filePath):   
            self.handle = open(filePath,"w")
            #self.handle.close()
t = TestFile()
t.openFile("test.txt")
os.remove("test.txt")
print("完成")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[34], line 8
#       6 t = TestFile()
#       7 t.openFile("test.txt")
# ----> 8 os.remove("test.txt")
#       9 print("完成")
#
# PermissionError: [WinError 32] 程序無法存取檔案，因為檔案正由另一個程序使用。: 'test.txt'

# %%
import os
class TestFile:
     def openFile(self,filePath):   
            with open(filePath,"w") as f:         
               f.write("Hello!")
t = TestFile()
t.openFile("test.txt")
os.remove("test.txt")
print("完成")
# Out:
# 完成

# %% [markdown]
# ## 壓縮與解壓縮 測試資料

# %%
import shutil
import os
try:
    os.mkdir('test2')
    print('建立目錄')
except:
    print('建立目錄失敗')

with open('./test2/test2.txt', 'a') as file2:
    file2.write('Programming is Fun.')
    print('完成附加檔案')
    
with open('./test2/test3.txt', 'a') as file2:
    file2.write('Programiz for beginners')
    print('完成附加檔案')
    
print('查看目錄內容')
os.listdir('./test2')
# Out:
# 建立目錄
# 完成附加檔案
# 完成附加檔案
# 查看目錄內容
# ['test2.txt', 'test3.txt']

# %% [markdown]
# ## 壓縮與解壓縮
# ### 但可以於Python程式內運用，可實現以下功能：
# #### 建立zip壓縮檔案
# + 透過zipfile.ZipFile( )建立物件，再透過物件的write()動作將資料夾壓縮。
# #### 解壓縮zip壓縮檔案
# + 透過zipfile.ZipFile( )建立物件，再透過物件的extractall()動作解壓縮。
# #### 列出zip壓縮檔案內容
# +透過zipfile.ZipFile( )建立物件，再透過物件的namelist()動作查看。

# %%
import zipfile
def create_zip(path):
  zf = zipfile.ZipFile(f'{path}.zip', 'w', zipfile.ZIP_DEFLATED)
  for root, dirs, files in os.walk(path):
    for file_name in files:
        path = os.path.join(root, file_name)
        print("path:",path)
        zf.write(path)
def ziplist(file_path):
  zf = zipfile.ZipFile(file_path, 'r')
  print(zf.namelist())
def extra_zip(file_path):
  zf = zipfile.ZipFile(file_path, 'r')
  zf.extractall()

try:
  print('壓縮資料')
  create_zip('test2')
except:
  print('壓縮失敗')

try:
  print('查看壓縮資料')
  ziplist('test2.zip')
except:
  print('查看壓縮資料失敗')

try:
  print('刪除目錄')
  shutil.rmtree("test2")
except:
  print('刪除目錄失敗')

try:
  print('解壓縮資料')
  extra_zip('test2.zip')
except:
  print('解壓縮失敗')
# Out:
# 壓縮資料
# path: test2\test2.txt
# path: test2\test3.txt
# 查看壓縮資料
# ['test2/test2.txt', 'test2/test3.txt']
# 刪除目錄
# 解壓縮資料

# %% [markdown]
# ## 爬蟲
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# pip install beautifulsoup4
#
# pip install html5lib

# %%
from bs4 import BeautifulSoup
html='''<a id='a1' class="c1">V1</a>
<a id='a2' class="c1">V2</a>
<a id='a3' class="c3">V3</a>
'''
soup = BeautifulSoup(html,"html5lib")
print(soup.find(id="a1"))
print(soup.find_all(class_="c1"))
# Out:
# <a class="c1" id="a1">V1</a>
# [<a class="c1" id="a1">V1</a>, <a class="c1" id="a2">V2</a>]

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\xvpow\appdata\roaming\python\python311\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
from bs4 import BeautifulSoup
html='''<a id='a1' class="c1" href="https://google.com">Google</a>
<a id='a2' class="c1"  href="https://yahoo.com">Yahoo</a>
<a id='a3' class="c3" href="https://facebook.com">Facebook</a>
'''
soup = BeautifulSoup(html,"html5lib")
print(soup.find(id="a1").getText())
print(soup.find(id="a1").get("href"))
tempList =  soup.find_all(class_="c1")
for tag in tempList:
    print(tag.get("href"),tag.getText())
# Out:
# Google
# https://google.com
# https://google.com Google
# https://yahoo.com Yahoo

# %%
import bs4
htmlFile = open("web1.html",encoding="utf-8",errors="ignore")
objSoup =  bs4.BeautifulSoup(htmlFile,"html5lib")
objectTag =  objSoup.find("h1")
print(objectTag.text)
objTagList = objSoup.find_all("h1")
for obj in objTagList:
    print(obj.text)
# Out:
# class與id練習測試h1標籤
# class與id練習測試h1標籤
# 國家首都資料表
# h1標籤測試1
# h1標籤測試2
# h1標籤測試3
# h1標籤測試4

# %%
import bs4
htmlFile = open("web1.html",encoding="utf-8",errors="ignore")
objSoup =  bs4.BeautifulSoup(htmlFile,"html5lib")
objTag =  objSoup.find_all("span",class_="class1")
for data in objTag:
    print(data)
# Out:
# <span class="class1">各種</span>

# %%
import bs4
htmlFile = open("web1.html",encoding="utf-8",errors="ignore")
objSoup =  bs4.BeautifulSoup(htmlFile,"html5lib")
objTagList =  objSoup.find_all("div",{'class':{'class1','class2'}})
for data in objTagList:
    print(data)
# Out:
# <div class="class1">故宮博物院</div>
# <div class="class2">日月潭</div>
# <div class="class2 class3">阿里山</div>

# %% [markdown]
# ## 電影排行榜

# %%
import requests
from bs4 import BeautifulSoup
url = "https://zh.wikipedia.org/zh-tw/2024年电影"
resp = requests.get(url)
resp.encoding = "utf-8"
soup = BeautifulSoup(resp.text,"html5lib")
movieTable = soup.find("table",class_="wikitable sortable")
tbody = movieTable.find("tbody")
trList = tbody.find_all("tr")
print(trList)
for inx in range(1,len(trList)):
    print("排名:",trList[inx].find("th").text,end="")
    print("片名:",trList[inx].select_one("a").text)
    print("全球票房:",trList[inx].find_all("td")[-1].text)
# Out:
# [<tr>
# <th>排名</th>
# <th>片名</th>
# <th>發行商</th>
# <th>全球票房
# </th></tr>, <tr>
# <th>1
# </th>
# <td style="background:#b6fcb6;">《<a href="/wiki/%E8%85%A6%E7%AD%8B%E6%80%A5%E8%BD%89%E5%BD%8E2" title="腦筋急轉彎2">腦筋急轉彎2</a>》†
# </td>
# <td><a href="/wiki/%E8%8F%AF%E7%89%B9%E8%BF%AA%E5%A3%AB%E5%B0%BC%E5%B7%A5%E4%BD%9C%E5%AE%A4%E9%9B%BB%E5%BD%B1" title="華特迪士尼工作室電影">迪士尼</a>
# </td>
# <td>$1,510,252,194
# </td></tr>, <tr>
# <th>2
# </th>
# <td>《<a href="/wiki/%E6%B2%99%E4%B8%98%EF%BC%9A%E7%AC%AC%E4%BA%8C%E9%83%A8" title="沙丘：第二部">沙丘：第二部</a>》
# </td>
# <td><a href="/wiki/%E5%8D%8E%E7%BA%B3%E5%85%84%E5%BC%9F%E5%BD%B1%E4%B8%9A" title="華納兄弟影業">華納兄弟</a>
# </td>
# <td>$711,844,358
# </td></tr>, <tr>
# <th>3
# </th>
# <td style="background:#b6fcb6;">《<a href="/wiki/%E7%A5%9E%E5%81%B7%E5%A5%B6%E7%88%B84" title="神偷奶爸4">神偷奶爸4</a>》†
# </td>
# <td><a href="/wiki/%E7%8E%AF%E7%90%83%E5%BD%B1%E4%B8%9A" title="環球影業">環球影業</a>
# </td>
# <td>$683,871,808
# </td></tr>, <tr>
# <th>4
# </th>
# <td>《<a href="/wiki/%E5%93%A5%E5%90%89%E6%8B%89%E8%88%87%E9%87%91%E5%89%9B%EF%BC%9A%E6%96%B0%E5%B8%9D%E5%9C%8B" title="哥吉拉與金剛：新帝國">哥吉拉與金剛：新帝國</a>》
# </td>
# <td><a href="/wiki/%E5%8D%8E%E7%BA%B3%E5%85%84%E5%BC%9F%E5%BD%B1%E4%B8%9A" title="華納兄弟影業">華納兄弟</a> / <a href="/wiki/%E6%9D%B1%E5%AF%B6" title="東寶">東寶</a>
# </td>
# <td>$567,650,016
# </td></tr>, <tr>
# <th>5
# </th>
# <td style="background:#b6fcb6;">《<a href="/wiki/%E6%AD%BB%E4%BE%8D%E8%88%87%E9%87%91%E9%8B%BC%E7%8B%BC" title="死侍與金鋼狼">死侍與金鋼狼</a>》†
# </td>
# <td><a href="/wiki/%E8%8F%AF%E7%89%B9%E8%BF%AA%E5%A3%AB%E5%B0%BC%E5%B7%A5%E4%BD%9C%E5%AE%A4%E9%9B%BB%E5%BD%B1" title="華特迪士尼工作室電影">迪士尼</a>
# </td>
# <td>$545,890,114
# </td></tr>, <tr>
# <th>6
# </th>
# <td>《<a href="/wiki/%E5%8A%9F%E5%A4%AB%E7%86%8A%E8%B2%934" title="功夫熊貓4">功夫熊貓4</a>》
# </td>
# <td><a href="/wiki/%E7%8E%AF%E7%90%83%E5%BD%B1%E4%B8%9A" title="環球影業">環球影業</a>
# </td>
# <td>$545,846,093
# </td></tr>, <tr>
# <th>7
# </th>
# <td>《<a href="/wiki/%E7%83%AD%E8%BE%A3%E6%BB%9A%E7%83%AB" title="熱辣滾燙">熱辣滾燙</a>》
# </td>
# <td><a href="/wiki/%E4%B8%AD%E5%9B%BD%E7%94%B5%E5%BD%B1%E9%9B%86%E5%9B%A2" title="中國電影集團">中國電影集團</a>
# </td>
# <td>$481,883,116
# </td></tr>, <tr>
# <th>8
# </th>
# <td>《<a href="/wiki/%E9%A3%9E%E9%A9%B0%E4%BA%BA%E7%94%9F2" title="飛馳人生2">飛馳人生2</a>》
# </td>
# <td><a href="/wiki/%E5%A4%A9%E6%B4%A5%E7%8C%AB%E7%9C%BC%E5%BE%AE%E5%BD%B1%E6%96%87%E5%8C%96%E4%BC%A0%E5%AA%92" title="天津貓眼微影文化傳媒">天津貓眼微影文化傳媒</a>
# </td>
# <td>$469,847,217
# </td></tr>, <tr>
# <th>9
# </th>
# <td style="background:#b6fcb6;">《<a href="/wiki/%E7%8C%A9%E7%90%83%E5%B4%9B%E8%B5%B7%EF%BC%9A%E7%8E%8B%E5%9C%8B%E8%AA%95%E7%94%9F" title="猩球崛起：王國誕生">猩球崛起：王國誕生</a>》†
# </td>
# <td><a href="/wiki/%E4%BA%8C%E5%8D%81%E4%B8%96%E7%B4%80%E5%BD%B1%E6%A5%AD" title="二十世紀影業">二十世紀影業</a> / <a href="/wiki/%E8%8F%AF%E7%89%B9%E8%BF%AA%E5%A3%AB%E5%B0%BC%E5%B7%A5%E4%BD%9C%E5%AE%A4%E9%9B%BB%E5%BD%B1" title="華特迪士尼工作室電影">迪士尼</a>
# </td>
# <td>$397,029,173
# </td></tr>, <tr>
# <th>10
# </th>
# <td style="background:#b6fcb6;">《<a href="/wiki/%E7%B5%95%E5%9C%B0%E6%88%B0%E8%AD%A6%EF%BC%9A%E7%94%9F%E6%AD%BB%E8%88%87%E5%85%B1" title="絕地戰警：生死與共">絕地戰警：生死與共</a>》†
# </td>
# <td><a href="/wiki/%E7%B4%A2%E5%B0%BC%E5%BD%B1%E8%A6%96%E5%A8%9B%E6%A8%82" title="索尼影視娛樂">索尼</a>
# </td>
# <td>$395,583,998
# </td></tr>]
# 排名: 1
# 片名: 腦筋急轉彎2
# 全球票房: $1,510,252,194
#
# 排名: 2
# 片名: 沙丘：第二部
# 全球票房: $711,844,358
#
# 排名: 3
# 片名: 神偷奶爸4
# 全球票房: $683,871,808
#
# 排名: 4
# 片名: 哥吉拉與金剛：新帝國
# 全球票房: $567,650,016
#
# 排名: 5
# 片名: 死侍與金鋼狼
# 全球票房: $545,890,114
#
# 排名: 6
# 片名: 功夫熊貓4
# 全球票房: $545,846,093
#
# 排名: 7
# 片名: 熱辣滾燙
# 全球票房: $481,883,116
#
# 排名: 8
# 片名: 飛馳人生2
# 全球票房: $469,847,217
#
# 排名: 9
# 片名: 猩球崛起：王國誕生
# 全球票房: $397,029,173
#
# 排名: 10
# 片名: 絕地戰警：生死與共
# 全球票房: $395,583,998

# %% [markdown]
# ## Numpy簡介

# %% [markdown]
# ## Numpy
# + 可做到的功能
#   + 快速的多維陣列操作。
#   + 可靠的科學功能函數庫。
#   + 可協助繪圖工具進行繪圖。
# + NumPy 是幾乎每個科學 Python 應用程序或模組的核心，它提供了以向量化形式的快速 N-d 陣列類型可供操作。

# %%
a = [1,2,3,4,5]
b = [4,5,6,7,8]
print(a + b)
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6, 7, 8]

# %%
import numpy as np
a = [1,2,3,4,5]
b = [4,5,6,7,8]
np1 = np.array(a)
np2 = np.array(b)
print(np1 + np2)
# Out:
# [ 5  7  9 11 13]

# %% [markdown]
# + ndarray.ndim
#    + 維度的數量。
# + ndarray.shape
#    + 顯示出陣列在每個維度上的整數值。
# + ndarray.size
#    + 陣列內元素的總數。
# + ndarray.dtype
#    + 用來描述陣列中元素類型的對象。
#    +
# https://numpy.org/doc/stable/user/basics.types.html

# %%
import numpy as np
i = [[1,2,3],
     [4,5,6]]
a = np.array(i,dtype=np.int8)
print(a.ndim)
print(a.shape)
print(a.size)
print(a.dtype)
# Out:
# 2
# (2, 3)
# 6
# int8
