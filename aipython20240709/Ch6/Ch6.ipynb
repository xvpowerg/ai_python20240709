# %%
priceList=[]
priceSum = 0
for i in range(1,5):
    p = int(input(f"請輸入{i}個月的支出金額"))
    priceSum =priceSum + p
    priceList.append(p)
priceList.sort()
print(f"max:{priceList[len(priceList)-1]}") 
print(f"min:{priceList[0]}")
print(priceSum)    
print(priceList) 

print(sum(priceList)) 
print(max(priceList))    
print(min(priceList))
# Out:
# 請輸入1個月的支出金額 5000
# 請輸入2個月的支出金額 4000
# 請輸入3個月的支出金額 3500
# 請輸入4個月的支出金額 7000
# max:7000
# min:3500
# 19500
# [3500, 4000, 5000, 7000]
# 19500
# 7000
# 3500

# %% [markdown]
# ## 物件導向入門

# %%
class Employee:#類別
    pass
emp = Employee()#物件   
print(emp)
emp.name = "Howard"
emp.salary = 50000
print("Name:",emp.name,"Salary:",emp.salary)

emp2 = Employee()
emp2.name = "Vivin"
emp2.salary = 25000
print("Name:",emp2.name,"Salary:",emp2.salary)
# Out:
# ...
# Name: Howard Salary: 50000
# Name: Vivin Salary: 25000

# %%
class Employee:
    def __init__(self,name = "Empty",salary=28000):
        self.name = name
        self.salary = salary
        
emp = Employee("Lucy",65000)
print(emp.name,emp.salary)
emp2 = Employee()
print(emp2.name,emp2.salary)
emp3 = Employee(salary = 35000)
print(emp3.name,emp3.salary)
emp4 = Employee(name="Ken")
print(emp4.name,emp4.salary)
# Out:
# Lucy 65000
# Empty 28000
# Empty 35000
# Ken 28000

# %%
class Person:
    def __init__(self,name="empty",age = 0):
        self.name = name
        self.age = age
    def printInfo(self):
        print("Name:",self.name,"Age:",self.age)
p1 = Person("Gigi",15)
p1.printInfo()
# Out:
# Name: Gigi Age: 15

# %%
class Employee:
    company = ""
    def __init__(self,firstName,age):
        self.firstName = firstName
        self.age = age
    def printInfo(self):
        print("Company:",Employee.company,"FristName:",self.firstName,"age:",self.age)
emp1 = Employee("Iris",20)
Employee.company = "IBM"#共用屬性 只要一個修改 所以物件都影響
emp1.printInfo()
emp2 = Employee("Joy",28)
emp2.printInfo()
# Out:
# Company: IBM FristName: Iris age: 20
# Company: IBM FristName: Joy age: 28

# %%
class Employee:
    company = ""
    def __init__(self,firstName,age):
        self.firstName = firstName
        self.age = age
        
    def printInfo(self):
        print("Company:",Employee.company,"FristName:",self.firstName,"age:",self.age)
    @classmethod    
    def setCompany(cls,companyName): 
        if len(companyName) == 0:
            print("錯誤的compay name")
        else:    
            cls.company = companyName
    @classmethod
    def getCompany(cls):
        return cls.company
        
emp1 = Employee("Iris",20)
Employee.setCompany("")
emp1.printInfo()
emp2 = Employee("Joy",28)
emp2.printInfo()

print("Company:",Employee.getCompany())
# Out:
# 錯誤的compay name
# Company:  FristName: Iris age: 20
# Company:  FristName: Joy age: 28
# Company:

# %% [markdown]
# ## 繼承

# %%
class Animal:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def printInfo(self):
        print(self.name,self.age)
an = Animal("Bobo",5)
an.printInfo()
# Out:
# Bobo 5

# %%
class Cat(Animal):
    pass
cat = Cat("Kitty",10)
cat.printInfo()
# Out:
# Kitty 10

# %% [markdown]
# ## 方法覆寫

# %%
class Animal:
    def __init__(self,name,age = 10):
        self.name = name
        self.age = age
    def run(self):
        print(self.name,"跑")
    def showAge(self):
        print(self.name,self.age)
    def eat(self):
        print(self.name,"吃")

# %%
class Cat(Animal):
    def eatFood(self,foodName):
        self.eat() 
        print(foodName)
cat1 = Cat("BoBo")
cat1.eatFood("魚")
# Out:
# BoBo 吃
# 魚

# %%
class Bird(Animal):
    def fly(self):
        print(self.name,"會飛")
    def  run(self):#複寫
        print("鳥",end="")
        super().run()#呼叫父類別的run
b1  =  Bird("DoDo",2)
b1.fly()
b1.run()
# Out:
# DoDo 會飛
# 鳥

# %% [markdown]
# ## 多重繼承與初始化方法
# ### 多重繼承
# + 繼承多個父類別時用，隔開
# + 注意成員搜尋的順序
#   + 從子類別開始
#   + 同一階層父類別由左至右搜尋
#   + 更上層祖父類別由左至右搜尋
#   + 直到達到頂層為止

# %%
class S():
    def method1(self):
        print("S.method1")
    def method2(self):
        print("S.method2")
class Z():
    def method1(self):
        print("Z.method1")
class A(S):
    def method3(self):
        print("A.method3")
class B(Z,S):
    def method2(self):
        print("B.method2")
    def method3(self):
        print("B.method3") 
class C(A,B):
    def method4(self):
        print("C.method4") 
c = C()
print(C.mro())
c.method4()
c.method3()
c.method2()
c.method1()
# Out:
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.Z'>, <class '__main__.S'>, <class 'object'>]
# C.method4
# A.method3
# B.method2
# Z.method1

# %% [markdown]
# ## 初始化方法

# %%
class Person:
    def __init__(self,name="Ken"):
        print("Person __init__")
        self.name = name
    def printInfo(self):
       print(self.name,"Hello")
class Student(Person):
    pass
class Teacher(Person):
    def __init__(self,name="Ken",score=10):
        print("Teacher Init")
        self.score = score
        super().__init__(name)
    def printInfo(self):
        print("score:",self.score)
        super().printInfo()
st1 = Student("Vivin")    
st1.printInfo()

t1 = Teacher(name="Lucy",score = 60)
t1.printInfo()
# Out:
# Person __init__
# Vivin Hello
# Teacher Init
# Person __init__
# score: 60
# Lucy Hello

# %%
class Point:
    def __init__(self,x = 0,y = 0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# (2,3)
# (-1,2)

# %% [markdown]
# ``` python
# __add__  +
#
# __iadd__  +=
#
# __sub__  -
#
# __isub__  -=
#
# __mul__  *
#
# __imul__  *=
#
# __truediv__   /
#
# __itruediv__   /=
#
# __floordiv__  //
#
# __ifloordiv__  //=
#
# __mod__  %
#
# __imod__  %=
#
# __pow__  **
#
# __ipow__  **=
# ```

# %%
class Point:
    def __init__(self,x = 0,y = 0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
print(p1 + p2)
# Out:
# (2,3)
# (-1,2)
# (1,5)

# %%
def showList(pList):
    for p in pList:
        print(p,end= "" )
class Point:
    def __init__(self,x = 0,y = 0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __len__(self): 
        self_len = (self.x ** 2) + (self.y ** 2)
        return self_len
    def __lt__(self,other):
        selfLen = len(self)
        otherLen = len(other)
        return selfLen < otherLen
    def __gt__(self,other):
        selfLen = len(self)
        otherLen = len(other)
        return selfLen > otherLen
p1 = Point(2,3)
p2 = Point(1,1)
p3 = Point(4,9)
p4 = Point(7,6)
print(len(p1))
print(p1 < p2)
print(p1 > p2)
pList = [p1,p2,p3,p4] 
pList.sort()
showList(pList)
# Out:
# 13
# False
# True
# (1,1)(2,3)(7,6)(4,9)

# %% [markdown]
# ## 目錄管理
#
# 我們可以使用 os 模組的 getcwd() 方法獲取當前工作目錄。
#
# 此方法以字串形式返回當前工作目錄。
#
# 請動手操作，並留意輸出結果

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\xvpow\aipython20240709\Ch6

# %%
import os
print(os.getcwd())
print(os.listdir())
fileList = os.listdir()
for f in fileList:
    print(f)
# Out:
# C:\Users\xvpow\aipython20240709\Ch6
# ['.ipynb_checkpoints', 'Ch6.ipynb', 'Untitled.ipynb']
# .ipynb_checkpoints
# Ch6.ipynb
# Untitled.ipynb

# %% [markdown]
# ## OverflowError
# ![image.png](attachment:e45c08fc-6cd5-4376-b9ce-c348648c5d5b.png)
